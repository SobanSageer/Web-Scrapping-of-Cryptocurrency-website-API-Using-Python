# %%
pip install requests beautifulsoup4
# Out:
# Requirement already satisfied: requests in c:\users\admin\anaconda3\lib\site-packages (2.31.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\admin\anaconda3\lib\site-packages (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\admin\anaconda3\lib\site-packages (from requests) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\admin\anaconda3\lib\site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\admin\anaconda3\lib\site-packages (from requests) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\admin\anaconda3\lib\site-packages (from requests) (2024.2.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\admin\anaconda3\lib\site-packages (from beautifulsoup4) (2.5)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Importing Libraries

# %%
import requests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

s ='coinbase_spot_btc'

# %%
class crypto(object):
    def scrape_data(self):
        pass
    def clean_data(self):
        pass
    def handle_missing_values(self):
        pass
    def scrape_crypto_prices(crypto_symbol):
        pass
    def calculate_log_returns(self):
        pass
    def save_to_csv(self):
        pass
    def display_data(self):
        pass
    def perform_analysis(self):
        pass
    def create_visualizations(self):
        pass
    def plot_historical_prices(self):
        pass
    def plot_mean_returns(self):
        pass
class bitcoin(crypto):
    def __init__(self):
        self.data = self.scrape_data()
    def scrape_data(self):
        url = "https://data.messari.io/api/v1/assets/bitcoin/metrics/price/time-series"
        try:
            response = requests.get(url, verify=True)
            response.raise_for_status()
            data = response.json()['data']['values']
            return pd.DataFrame(data)
        except requests.exceptions.RequestException as e:
            print("Error fetching data for bitcoin: {}".format(e))
            return None
    def clean_data(self):
        self.data.columns = ['time', 'opening_price', 'closing_price', 'high', 'low', 'volume']
        self.data = self.data.dropna()
    def handle_missing_values(self):
        for column in self.data.columns:
            self.data[column] = self.data[column].fillna(self.data[column].mean())
    def calculate_log_returns(self):
        price_columns = ['opening_price', 'closing_price', 'high', 'low']
        for col in price_columns:
            self.data[f'{col}_log_return'] = np.log(self.data[col] / self.data[col].shift(1))

    def save_to_csv(self):
        if self.data is not None:
            csv_filename = "bitcoin_data.csv"
            self.data.to_csv(csv_filename, index=False)
            print("\nData for bitcoin saved to {}".format(csv_filename))
        else:
            print("Failed to save data for bitcoin")

    def display_data(self):
        print("\nData for bitcoin After Handling Missing Values and Calculating Log Returns:")
        print(self.data.head())

    def perform_analysis(self):
        print("\nAnalysis for bitcoin:")
        for col in ['opening_price', 'closing_price', 'high', 'low']:
            mean_return = self.data[col].mean()
            median_return = self.data[col].median()
            std_dev_return = self.data[col].std()

            print("\nAnalysis for {}:".format(col))
            print("Mean: ", mean_return)
            print("Median: ", median_return)
            print("Standard Deviation: ", std_dev_return)

            max_return_date = self.data.loc[self.data[col].idxmax(), 'time']
            max_return_value = self.data[col].max()

            print("\nDate with the Highest Return for {}:".format(col))
            print("Date: {}".format(max_return_date))
            print("Highest Return Value: {}".format(max_return_value))

    def create_visualizations(self):
        self.plot_historical_prices()
        self.plot_mean_returns()
    def plot_historical_prices(self):
        plt.figure(figsize=(9, 6))
        plt.plot(self.data['time'], self.data['closing_price'], label='Closing Price', color='green', marker='o')
        plt.title("Historical Prices of bitcoin")
        plt.xlabel("Date")
        plt.ylabel("Closing Price")
        plt.grid(True)
        plt.savefig("bitcoin_historical_prices.png")
        plt.show()
    def plot_mean_returns(self):
        price_columns = ['opening_price', 'closing_price', 'high', 'low']
        mean_returns = self.data[[col for col in price_columns]].mean()

        plt.figure(figsize=(8, 5))
        mean_returns.plot(kind='bar', color=['yellow', 'indigo', 'beige', 'pink'])
        plt.title("Mean Returns of bitcoin")
        plt.xlabel("Price Type")
        plt.ylabel("Mean Return")
        plt.savefig("bitcoin_mean_returns.png")
        plt.show()
class xrp(crypto):
    def __init__(self):
        self.data = self.scrape_data()
    def scrape_data(self):
        url = "https://data.messari.io/api/v1/assets/xrp/metrics/price/time-series"
        try:
            response = requests.get(url, verify=True)
            response.raise_for_status()
            data = response.json()['data']['values']
            return pd.DataFrame(data)
        except requests.exceptions.RequestException as e:
            print("Error fetching data for xrp: {}".format(e))
            return None
    def clean_data(self):
        self.data.columns = ['time', 'opening_price', 'closing_price', 'high', 'low', 'volume']
        self.data = self.data.dropna()
    def handle_missing_values(self):
        for column in self.data.columns:
            self.data[column] = self.data[column].fillna(self.data[column].mean())
    def calculate_log_returns(self):
        price_columns = ['opening_price', 'closing_price', 'high', 'low']
        for col in price_columns:
            self.data[f'{col}_log_return'] = np.log(self.data[col] / self.data[col].shift(1))

    def save_to_csv(self):
        if self.data is not None:
            csv_filename = "xrp_data.csv"
            self.data.to_csv(csv_filename, index=False)
            print("\nData for xrp saved to {}".format(csv_filename))
        else:
            print("Failed to save data for xrp")

    def display_data(self):
        print("\nData for xrp After Handling Missing Values and Calculating Log Returns:")
        print(self.data.head())

    def perform_analysis(self):
        print("\nAnalysis for xrp:")
        for col in ['opening_price', 'closing_price', 'high', 'low']:
            mean_return = self.data[col].mean()
            median_return = self.data[col].median()
            std_dev_return = self.data[col].std()

            print("\nAnalysis for {}:".format(col))
            print("Mean: ", mean_return)
            print("Median: ", median_return)
            print("Standard Deviation: ", std_dev_return)

            max_return_date = self.data.loc[self.data[col].idxmax(), 'time']
            max_return_value = self.data[col].max()

            print("\nDate with the Highest Return for {}:".format(col))
            print("Date: {}".format(max_return_date))
            print("Highest Return Value: {}".format(max_return_value))

    def create_visualizations(self):
        self.plot_historical_prices()
        self.plot_mean_returns()
    def plot_historical_prices(self):
        plt.figure(figsize=(9, 6))
        plt.plot(self.data['time'], self.data['closing_price'], label='Closing Price', color='green', marker='o')
        plt.title("Historical Prices of xrp")
        plt.xlabel("Date")
        plt.ylabel("Closing Price")
        plt.grid(True)
        plt.savefig("xrp_historical_prices.png")
        plt.show()
    def plot_mean_returns(self):
        price_columns = ['opening_price', 'closing_price', 'high', 'low']
        mean_returns = self.data[[col for col in price_columns]].mean()

        plt.figure(figsize=(8, 5))
        mean_returns.plot(kind='bar', color=['yellow', 'indigo', 'beige', 'pink'])
        plt.title("Mean Returns of xrp")
        plt.xlabel("Price Type")
        plt.ylabel("Mean Return")
        plt.savefig("xrp_mean_returns.png")
        plt.show()
class ethereum(crypto):
    def __init__(self):
        self.data = self.scrape_data()
    def scrape_data(self):
        url = "https://data.messari.io/api/v1/assets/ethereum/metrics/price/time-series"
        try:
            response = requests.get(url, verify=True)
            response.raise_for_status()
            data = response.json()['data']['values']
            return pd.DataFrame(data)
        except requests.exceptions.RequestException as e:
            print("Error fetching data for ethereum: {}".format( e))
            return None
    def clean_data(self):
        self.data.columns = ['time', 'opening_price', 'closing_price', 'high', 'low', 'volume']
        self.data = self.data.dropna()
    def handle_missing_values(self):
        for column in self.data.columns:
            self.data[column] = self.data[column].fillna(self.data[column].mean())
    def scrape_crypto_prices(crypto_symbol):
        pass
    def calculate_log_returns(self):
        price_columns = ['opening_price', 'closing_price', 'high', 'low']
        for col in price_columns:
            self.data[f'{col}_log_return'] = np.log(self.data[col] / self.data[col].shift(1))

    def save_to_csv(self):
        if self.data is not None:
            csv_filename = "ethereum_data.csv"
            self.data.to_csv(csv_filename, index=False)
            print("\nData for ethereum saved to {}".format(csv_filename))
        else:
            print("Failed to save data for ethereum")

    def display_data(self):
        print("\nData for ethereum After Handling Missing Values and Calculating Log Returns:")
        print(self.data.head())

    def perform_analysis(self):
        print("\nAnalysis for ethereum:")
        for col in ['opening_price', 'closing_price', 'high', 'low']:
            mean_return = self.data[col].mean()
            median_return = self.data[col].median()
            std_dev_return = self.data[col].std()

            print("\nAnalysis for {}:".format(col))
            print("Mean: ", mean_return)
            print("Median: ", median_return)
            print("Standard Deviation: ", std_dev_return)

            max_return_date = self.data.loc[self.data[col].idxmax(), 'time']
            max_return_value = self.data[col].max()

            print("\nDate with the Highest Return for {}:".format(col))
            print("Date: {}".format(max_return_date))
            print("Highest Return Value: {}".format(max_return_value))

    def create_visualizations(self):
        self.plot_historical_prices()
        self.plot_mean_returns()
    def plot_historical_prices(self):
        plt.figure(figsize=(9, 6))
        plt.plot(self.data['time'], self.data['closing_price'], label='Closing Price', color='green', marker='o')
        plt.title("Historical Prices of ethereum")
        plt.xlabel("Date")
        plt.ylabel("Closing Price")
        plt.grid(True)
        plt.savefig("ethereum_historical_prices.png")
        plt.show()
    def plot_mean_returns(self):
        price_columns = ['opening_price', 'closing_price', 'high', 'low']
        mean_returns = self.data[[col for col in price_columns]].mean()

        plt.figure(figsize=(8, 5))
        mean_returns.plot(kind='bar', color=['yellow', 'indigo', 'beige', 'pink'])
        plt.title("Mean Returns of ethereum")
        plt.xlabel("Price Type")
        plt.ylabel("Mean Return")
        plt.savefig("ethereum_mean_returns.png")
        plt.show()

# %%
b_obj=bitcoin()
b_obj.clean_data()
b_obj.handle_missing_values()
b_obj.display_data()
b_obj.perform_analysis()
b_obj.plot_historical_prices()
b_obj.calculate_log_returns()
b_obj.plot_mean_returns()
b_obj.create_visualizations()
b_obj.save_to_csv()
# Out:
# Data for bitcoin After Handling Missing Values and Calculating Log Returns:
#             time  opening_price  closing_price          high           low  \
# 0  1712246400000   67671.766366   68122.934859  67563.473978  67865.077992
# 1  1712250000000   67868.601145   68873.088460  67789.746652  68851.310177
# 2  1712253600000   68872.707215   69266.231812  68619.005364  68619.005364
# 3  1712257200000   68626.462921   69112.741438  68454.828990  68516.955691
# 4  1712260800000   68494.433197   68581.146612  67418.024624  67944.007988
#
#          volume
# 0  1.466334e+09
# 1  1.821178e+09
# 2  3.130615e+09
# 3  2.008821e+09
# 4  2.659132e+09
#
# Analysis for bitcoin:
#
# Analysis for opening_price:
# Mean:  68517.70725124645
# Median:  68990.35998160345
# Standard Deviation:  2174.338249847049
#
# Date with the Highest Return for opening_price:
# Date: 1712577600000
# Highest Return Value: 72378.5119093158
#
# Analysis for closing_price:
# Mean:  68784.71076740162
# Median:  69171.66272920683
# Standard Deviation:  2106.7796159302698
#
# Date with the Highest Return for closing_price:
# Date: 1712577600000
# Highest Return Value: 72713.14833515791
#
# Analysis for high:
# Mean:  68226.11346301013
# Median:  68649.02896806283
# Standard Deviation:  2266.58958675935
#
# Date with the Highest Return for high:
# Date: 1712574000000
# Highest Return Value: 72220.48026721599
#
# Analysis for low:
# Mean:  68511.9274582239
# Median:  68991.90082174304
# Standard Deviation:  2178.5433669143154
#
# Date with the Highest Return for low:
# Date: 1712574000000
# Highest Return Value: 72374.19096835743
# Data for bitcoin saved to bitcoin_data.csv

# %%
e_obj=ethereum()
e_obj.clean_data()
e_obj.handle_missing_values()
e_obj.display_data()
e_obj.perform_analysis()
e_obj.plot_historical_prices()
e_obj.calculate_log_returns()
e_obj.plot_mean_returns()
e_obj.create_visualizations()
e_obj.save_to_csv()
# Out:
# Data for ethereum After Handling Missing Values and Calculating Log Returns:
#             time  opening_price  closing_price         high          low  \
# 0  1712246400000    3365.056228    3389.915649  3362.219700  3378.160689
# 1  1712250000000    3378.125042    3416.118268  3374.492930  3413.732811
# 2  1712253600000    3413.631665    3439.617158  3380.242457  3381.127739
# 3  1712257200000    3381.137232    3389.381856  3364.339279  3367.745044
# 4  1712260800000    3367.836934    3370.237677  3284.270006  3325.921816
#
#          volume
# 0  4.224170e+08
# 1  4.925239e+08
# 2  9.329738e+08
# 3  5.379848e+08
# 4  1.444299e+09
#
# Analysis for ethereum:
#
# Analysis for opening_price:
# Mean:  3386.6580929662073
# Median:  3389.8577148726754
# Standard Deviation:  180.93969118161078
#
# Date with the Highest Return for opening_price:
# Date: 1712617200000
# Highest Return Value: 3723.814547470353
#
# Analysis for closing_price:
# Mean:  3402.3140586986656
# Median:  3401.198698757272
# Standard Deviation:  177.81141894152915
#
# Date with the Highest Return for closing_price:
# Date: 1712613600000
# Highest Return Value: 3727.636934537522
#
# Analysis for high:
# Mean:  3368.6401429953116
# Median:  3380.844607567612
# Standard Deviation:  186.2017240176863
#
# Date with the Highest Return for high:
# Date: 1712617200000
# Highest Return Value: 3692.162262364331
#
# Analysis for low:
# Mean:  3386.1230376661533
# Median:  3389.768575562788
# Standard Deviation:  181.1896541942154
#
# Date with the Highest Return for low:
# Date: 1712613600000
# Highest Return Value: 3725.0209189586344
# Data for ethereum saved to ethereum_data.csv

# %%
r_obj=xrp()
r_obj.clean_data()
r_obj.handle_missing_values()
r_obj.display_data()
r_obj.perform_analysis()
r_obj.plot_historical_prices()
r_obj.calculate_log_returns()
r_obj.plot_mean_returns()
r_obj.create_visualizations()
r_obj.save_to_csv()
# Out:
# Data for xrp After Handling Missing Values and Calculating Log Returns:
#             time  opening_price  closing_price      high       low  \
# 0  1712246400000       0.594154       0.599568  0.594116  0.598851
# 1  1712250000000       0.598514       0.604091  0.598493  0.603337
# 2  1712253600000       0.603280       0.605076  0.597350  0.598125
# 3  1712257200000       0.598152       0.600364  0.596434  0.596434
# 4  1712260800000       0.596414       0.596558  0.585901  0.591171
#
#          volume
# 0  7.665242e+07
# 1  7.396246e+07
# 2  7.174992e+07
# 3  4.474389e+07
# 4  9.823332e+07
#
# Analysis for xrp:
#
# Analysis for opening_price:
# Mean:  0.5807442460617315
# Median:  0.5943622228893866
# Standard Deviation:  0.04359302062313677
#
# Date with the Highest Return for opening_price:
# Date: 1712667600000
# Highest Return Value: 0.630142935662348
#
# Analysis for closing_price:
# Mean:  0.5835790881236184
# Median:  0.5960307817526784
# Standard Deviation:  0.04234721312674323
#
# Date with the Highest Return for closing_price:
# Date: 1712664000000
# Highest Return Value: 0.6406568812813684
#
# Analysis for high:
# Mean:  0.5771918515176149
# Median:  0.5926790317161836
# Standard Deviation:  0.04529134478053448
#
# Date with the Highest Return for high:
# Date: 1712667600000
# Highest Return Value: 0.624456224351918
#
# Analysis for low:
# Mean:  0.5804313576570976
# Median:  0.5944007929781961
# Standard Deviation:  0.04377996643190467
#
# Date with the Highest Return for low:
# Date: 1712664000000
# Highest Return Value: 0.6304623042689305
# Data for xrp saved to xrp_data.csv
